# %%
import torch
from tvm import relay

# %% [markdown]
# ## Load Model

# %%
from mmdet.apis import init_detector

config = '/home/austin/work/3rd/mmdetection/configs/yolo/yolov3_d53_mstrain-416_273e_coco.py'
checkpoint = '/workspace/datasets/mmcv/models/yolov3_d53_mstrain-416_273e_coco-2b60fcd9.pth'

# initialize the detector
model = init_detector(config, checkpoint, device='cpu')
# Out:
# load checkpoint from local path: /workspace/datasets/mmcv/models/yolov3_d53_mstrain-416_273e_coco-2b60fcd9.pth

# %% [markdown]
# 搜索resize参数：

# %%
test_pipeline = model.cfg.test_pipeline
img_scale = [_dict['img_scale']for _dict in test_pipeline if 'img_scale' in _dict]
assert len(img_scale) == 1 # should only has one 'img_scale'
img_scale = img_scale[0]

# %% [markdown]
# ## Trace Model
#
# 由于mmdetection的`model.forward()`包含了nms等后处理，因此这里替换`forward()`为`forward_dummy()`：

# %%
from copy import deepcopy

_model = deepcopy(model)
_model.forward = _model.forward_dummy

# %%
input_data = torch.randn((1, 3, *img_scale))
scripted_model = torch.jit.trace(_model, input_data).eval()
# Out:
# /home/austin/work/3rd/mmdetection/mmdet/models/dense_heads/yolo_head.py:126: UserWarning: DeprecationWarning: `anchor_generator` is deprecated, please use "prior_generator" instead
#   warnings.warn('DeprecationWarning: `anchor_generator` is deprecated, '
# /home/austin/work/3rd/mmdetection/mmdet/models/dense_heads/yolo_head.py:136: UserWarning: DeprecationWarning: `num_anchors` is deprecated, please use "num_base_priors" instead
#   warnings.warn('DeprecationWarning: `num_anchors` is deprecated, '

# %%
shape_list = [('input', input_data.shape)]
mod, params = relay.frontend.from_pytorch(
    scripted_model, shape_list, use_parser_friendly_name=True)

# %%
mod['main']
# Out:
# fn (%input: Tensor[(1, 3, 416, 416), float32], %backbone_conv1_conv_weight: Tensor[(32, 3, 3, 3), float32], %backbone_conv1_bn_weight: Tensor[(32), float32], %backbone_conv1_bn_bias: Tensor[(32), float32], %backbone_conv1_bn_running_mean: Tensor[(32), float32], %backbone_conv1_bn_running_var: Tensor[(32), float32], %backbone_conv_res_block1_conv_conv_weight: Tensor[(64, 32, 3, 3), float32], %backbone_conv_res_block1_conv_bn_weight: Tensor[(64), float32], %backbone_conv_res_block1_conv_bn_bias: Tensor[(64), float32], %backbone_conv_res_block1_conv_bn_running_mean: Tensor[(64), float32], %backbone_conv_res_block1_conv_bn_running_var: Tensor[(64), float32], %backbone_conv_res_block1_res0_conv1_conv_weight: Tensor[(32, 64, 1, 1), float32], %backbone_conv_res_block1_res0_conv1_bn_weight: Tensor[(32), float32], %backbone_conv_res_block1_res0_conv1_bn_bias: Tensor[(32), float32], %backbone_conv_res_block1_res0_conv1_bn_running_mean: Tensor[(32), float32], %backbone_conv_res_block1_res0_conv1_bn_running_var: Tensor[(32), float32], %backbone_conv_res_block1_res0_conv2_conv_weight: Tensor[(64, 32, 3, 3), float32], %backbone_conv_res_block1_res0_conv2_bn_weight: Tensor[(64), float32], %backbone_conv_res_block1_res0_conv2_bn_bias: Tensor[(64), float32], %backbone_conv_res_block1_res0_conv2_bn_running_mean: Tensor[(64), float32], %backbone_conv_res_block1_res0_conv2_bn_running_var: Tensor[(64), float32], %backbone_conv_res_block2_conv_conv_weight: Tensor[(128, 64, 3, 3), float32], %backbone_conv_res_block2_conv_bn_weight: Tensor[(128), float32], %backbone_conv_res_block2_conv_bn_bias: Tensor[(128), float32], %backbone_conv_res_block2_conv_bn_running_mean: Tensor[(128), float32], %backbone_conv_res_block2_conv_bn_running_var: Tensor[(128), float32], %backbone_conv_res_block2_res0_conv1_conv_weight: Tensor[(64, 128, 1, 1), float32], %backbone_conv_res_block2_res0_conv1_bn_weight: Tensor[(64), float32], %backbone_conv_res_block2_res0_conv1_bn_bias: Tensor[(64), float32], %backbone_conv_res_block2_res0_conv1_bn_running_mean: Tensor[(64), float32], %backbone_conv_res_block2_res0_conv1_bn_running_var: Tensor[(64), float32], %backbone_conv_res_block2_res0_conv2_conv_weight: Tensor[(128, 64, 3, 3), float32], %backbone_conv_res_block2_res0_conv2_bn_weight: Tensor[(128), float32], %backbone_conv_res_block2_res0_conv2_bn_bias: Tensor[(128), float32], %backbone_conv_res_block2_res0_conv2_bn_running_mean: Tensor[(128), float32], %backbone_conv_res_block2_res0_conv2_bn_running_var: Tensor[(128), float32], %backbone_conv_res_block2_res1_conv1_conv_weight: Tensor[(64, 128, 1, 1), float32], %backbone_conv_res_block2_res1_conv1_bn_weight: Tensor[(64), float32], %backbone_conv_res_block2_res1_conv1_bn_bias: Tensor[(64), float32], %backbone_conv_res_block2_res1_conv1_bn_running_mean: Tensor[(64), float32], %backbone_conv_res_block2_res1_conv1_bn_running_var: Tensor[(64), float32], %backbone_conv_res_block2_res1_conv2_conv_weight: Tensor[(128, 64, 3, 3), float32], %backbone_conv_res_block2_res1_conv2_bn_weight: Tensor[(128), float32], %backbone_conv_res_block2_res1_conv2_bn_bias: Tensor[(128), float32], %backbone_conv_res_block2_res1_conv2_bn_running_mean: Tensor[(128), float32], %backbone_conv_res_block2_res1_conv2_bn_running_var: Tensor[(128), float32], %backbone_conv_res_block3_conv_conv_weight: Tensor[(256, 128, 3, 3), float32], %backbone_conv_res_block3_conv_bn_weight: Tensor[(256), float32], %backbone_conv_res_block3_conv_bn_bias: Tensor[(256), float32], %backbone_conv_res_block3_conv_bn_running_mean: Tensor[(256), float32], %backbone_conv_res_block3_conv_bn_running_var: Tensor[(256), float32], %backbone_conv_res_block3_res0_conv1_conv_weight: Tensor[(128, 256, 1, 1), float32], %backbone_conv_res_block3_res0_conv1_bn_weight: Tensor[(128), float32], %backbone_conv_res_block3_res0_conv1_bn_bias: Tensor[(128), float32], %backbone_conv_res_block3_res0_conv1_bn_running_mean: Tensor[(128), float32], %backbone_conv_res_block3_res0_conv1_bn_running_var: Tensor[( ...
#   %0 = nn.conv2d(%input, %backbone_conv1_conv_weight, padding=[1, 1, 1, 1], channels=32, kernel_size=[3, 3]);
#   %1 = nn.batch_norm(%0, %backbone_conv1_bn_weight, %backbone_conv1_bn_bias, %backbone_conv1_bn_running_mean, %backbone_conv1_bn_running_var);
#   %2 = %1.0;
#   %3 = nn.leaky_relu(%2, alpha=0.1f);
#   %4 = nn.conv2d(%3, %backbone_conv_res_block1_conv_conv_weight, strides=[2, 2], padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3]);
#   %5 = nn.batch_norm(%4, %backbone_conv_res_block1_conv_bn_weight, %backbone_conv_res_block1_conv_bn_bias, %backbone_conv_res_block1_conv_bn_running_mean, %backbone_conv_res_block1_conv_bn_running_var);
#   %6 = %5.0;
#   %7 = nn.leaky_relu(%6, alpha=0.1f);
#   %8 = nn.conv2d(%7, %backbone_conv_res_block1_res0_conv1_conv_weight, padding=[0, 0, 0, 0], channels=32, kernel_size=[1, 1]);
#   %9 = nn.batch_norm(%8, %backbone_conv_res_block1_res0_conv1_bn_weight, %backbone_conv_res_block1_res0_conv1_bn_bias, %backbone_conv_res_block1_res0_conv1_bn_running_mean, %backbone_conv_res_block1_res0_conv1_bn_running_var);
#   %10 = %9.0;
#   %11 = nn.leaky_relu(%10, alpha=0.1f);
#   %12 = nn.conv2d(%11, %backbone_conv_res_block1_res0_conv2_conv_weight, padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3]);
#   %13 = nn.batch_norm(%12, %backbone_conv_res_block1_res0_conv2_bn_weight, %backbone_conv_res_block1_res0_conv2_bn_bias, %backbone_conv_res_block1_res0_conv2_bn_running_mean, %backbone_conv_res_block1_res0_conv2_bn_running_var);
#   %14 = %13.0;
#   %15 = nn.leaky_relu(%14, alpha=0.1f);
#   %16 = add(%15, %7);
#   %17 = nn.conv2d(%16, %backbone_conv_res_block2_conv_conv_weight, strides=[2, 2], padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3]);
#   %18 = nn.batch_norm(%17, %backbone_conv_res_block2_conv_bn_weight, %backbone_conv_res_block2_conv_bn_bias, %backbone_conv_res_block2_conv_bn_running_mean, %backbone_conv_res_block2_conv_bn_running_var);
#   %19 = %18.0;
#   %20 = nn.leaky_relu(%19, alpha=0.1f);
#   %21 = nn.conv2d(%20, %backbone_conv_res_block2_res0_conv1_conv_weight, padding=[0, 0, 0, 0], channels=64, kernel_size=[1, 1]);
#   %22 = nn.batch_norm(%21, %backbone_conv_res_block2_res0_conv1_bn_weight, %backbone_conv_res_block2_res0_conv1_bn_bias, %backbone_conv_res_block2_res0_conv1_bn_running_mean, %backbone_conv_res_block2_res0_conv1_bn_running_var);
#   %23 = %22.0;
#   %24 = nn.leaky_relu(%23, alpha=0.1f);
#   %25 = nn.conv2d(%24, %backbone_conv_res_block2_res0_conv2_conv_weight, padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3]);
#   %26 = nn.batch_norm(%25, %backbone_conv_res_block2_res0_conv2_bn_weight, %backbone_conv_res_block2_res0_conv2_bn_bias, %backbone_conv_res_block2_res0_conv2_bn_running_mean, %backbone_conv_res_block2_res0_conv2_bn_running_var);
#   %27 = %26.0;
#   %28 = nn.leaky_relu(%27, alpha=0.1f);
#   %29 = add(%28, %20);
#   %30 = nn.conv2d(%29, %backbone_conv_res_block2_res1_conv1_conv_weight, padding=[0, 0, 0, 0], channels=64, kernel_size=[1, 1]);
#   %31 = nn.batch_norm(%30, %backbone_conv_res_block2_res1_conv1_bn_weight, %backbone_conv_res_block2_res1_conv1_bn_bias, %backbone_conv_res_block2_res1_conv1_bn_running_mean, %backbone_conv_res_block2_res1_conv1_bn_running_var);
#   %32 = %31.0;
#   %33 = nn.leaky_relu(%32, alpha=0.1f);
#   %34 = nn.conv2d(%33, %backbone_conv_res_block2_res1_conv2_conv_weight, padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3]);
#   %35 = nn.batch_norm(%34, %backbone_conv_res_block2_res1_conv2_bn_weight, %backbone_conv_res_block2_res1_conv2_bn_bias, %backbone_conv_res_block2_res1_conv2_bn_running_mean, %backbone_conv_res_block2_res1_conv2_bn_running_var);
#   %36 = %35.0;
#   %37 = nn.leaky_relu(%36, alpha=0.1f);
#   %38 = add(%37, %29);
#   %39 = nn.conv2d(%38, %backbone_conv_res_block3_conv_conv_weight, strides=[2, 2], padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]);
#   %40 = nn.batch_norm(%39, %backbone_conv_res_block3_conv_bn_weight, %backbone_conv_res_block3_conv_bn_bias, %backbone_conv_res_block3_conv_bn_running_mean, %backbone_conv_res_block3_conv_bn_running_var);
#   %41 = %40.0;
#   %42 = nn.leaky_relu(%41, alpha=0.1f);
#   %43 = nn.conv2d(%42, %backbone_conv_res_block3_res0_conv1_conv_weight, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %44 = nn.batch_norm(%43, %backbone_conv_res_block3_res0_conv1_bn_weight, %backbone_conv_res_block3_res0_conv1_bn_bias, %backbone_conv_res_block3_res0_conv1_bn_running_mean, %backbone_conv_res_block3_res0_conv1_bn_running_var);
#   %45 = %44.0;
#   %46 = nn.leaky_relu(%45, alpha=0.1f);
#   %47 = nn.conv2d(%46, %backbone_conv_res_block3_res0_conv2_conv_weight, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]);
#   %48 = nn.batch_norm(%47, %backbone_conv_res_block3_res0_conv2_bn_weight, %backbone_conv_res_block3_res0_conv2_bn_bias, %backbone_conv_res_block3_res0_conv2_bn_running_mean, %backbone_conv_res_block3_res0_conv2_bn_running_var);
#   %49 = %48.0;
#   %50 = nn.leaky_relu(%49, alpha=0.1f);
#   %51 = add(%50, %42);
#   %52 = nn.conv2d(%51, %backbone_conv_res_block3_res1_conv1_conv_weight, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %53 = nn.batch_norm(%52, %backbone_conv_res_block3_res1_conv1_bn_weight, %backbone_conv_res_block3_res1_conv1_bn_bias, %backbone_conv_res_block3_res1_conv1_bn_running_mean, %backbone_conv_res_block3_res1_conv1_bn_running_var);
#   %54 = %53.0;
#   %55 = nn.leaky_relu(%54, alpha=0.1f);
#   %56 = nn.conv2d(%55, %backbone_conv_res_block3_res1_conv2_conv_weight, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]);
#   %57 = nn.batch_norm(%56, %backbone_conv_res_block3_res1_conv2_bn_weight, %backbone_conv_res_block3_res1_conv2_bn_bias, %backbone_conv_res_block3_res1_conv2_bn_running_mean, %backbone_conv_res_block3_res1_conv2_bn_running_var);
#   %58 = %57.0;
#   %59 = nn.leaky_relu(%58, alpha=0.1f);
#   %60 = add(%59, %51);
#   %61 = nn.conv2d(%60, %backbone_conv_res_block3_res2_conv1_conv_weight, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %62 = nn.batch_norm(%61, %backbone_conv_res_block3_res2_conv1_bn_weight, %backbone_conv_res_block3_res2_conv1_bn_bias, %backbone_conv_res_block3_res2_conv1_bn_running_mean, %backbone_conv_res_block3_res2_conv1_bn_running_var);
#   %63 = %62.0;
#   %64 = nn.leaky_relu(%63, alpha=0.1f);
#   %65 = nn.conv2d(%64, %backbone_conv_res_block3_res2_conv2_conv_weight, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]);
#   %66 = nn.batch_norm(%65, %backbone_conv_res_block3_res2_conv2_bn_weight, %backbone_conv_res_block3_res2_conv2_bn_bias, %backbone_conv_res_block3_res2_conv2_bn_running_mean, %backbone_conv_res_block3_res2_conv2_bn_running_var);
#   %67 = %66.0;
#   %68 = nn.leaky_relu(%67, alpha=0.1f);
#   %69 = add(%68, %60);
#   %70 = nn.conv2d(%69, %backbone_conv_res_block3_res3_conv1_conv_weight, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %71 = nn.batch_norm(%70, %backbone_conv_res_block3_res3_conv1_bn_weight, %backbone_conv_res_block3_res3_conv1_bn_bias, %backbone_conv_res_block3_res3_conv1_bn_running_mean, %backbone_conv_res_block3_res3_conv1_bn_running_var);
#   %72 = %71.0;
#   %73 = nn.leaky_relu(%72, alpha=0.1f);
#   %74 = nn.conv2d(%73, %backbone_conv_res_block3_res3_conv2_conv_weight, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]);
#   %75 = nn.batch_norm(%74, %backbone_conv_res_block3_res3_conv2_bn_weight, %backbone_conv_res_block3_res3_conv2_bn_bias, %backbone_conv_res_block3_res3_conv2_bn_running_mean, %backbone_conv_res_block3_res3_conv2_bn_running_var);
#   %76 = %75.0;
#   %77 = nn.leaky_relu(%76, alpha=0.1f);
#   %78 = add(%77, %69);
#   %79 = nn.conv2d(%78, %backbone_conv_res_block3_res4_conv1_conv_weight, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %80 = nn.batch_norm(%79, %backbone_conv_res_block3_res4_conv1_bn_weight, %backbone_conv_res_block3_res4_conv1_bn_bias, %backbone_conv_res_block3_res4_conv1_bn_running_mean, %backbone_conv_res_block3_res4_conv1_bn_running_var);
#   %81 = %80.0;
#   %82 = nn.leaky_relu(%81, alpha=0.1f);
#   %83 = nn.conv2d(%82, %backbone_conv_res_block3_res4_conv2_conv_weight, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]);
#   %84 = nn.batch_norm(%83, %backbone_conv_res_block3_res4_conv2_bn_weight, %backbone_conv_res_block3_res4_conv2_bn_bias, %backbone_conv_res_block3_res4_conv2_bn_running_mean, %backbone_conv_res_block3_res4_conv2_bn_running_var);
#   %85 = %84.0;
#   %86 = nn.leaky_relu(%85, alpha=0.1f);
#   %87 = add(%86, %78);
#   %88 = nn.conv2d(%87, %backbone_conv_res_block3_res5_conv1_conv_weight, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %89 = nn.batch_norm(%88, %backbone_conv_res_block3_res5_conv1_bn_weight, %backbone_conv_res_block3_res5_conv1_bn_bias, %backbone_conv_res_block3_res5_conv1_bn_running_mean, %backbone_conv_res_block3_res5_conv1_bn_running_var);
#   %90 = %89.0;
#   %91 = nn.leaky_relu(%90, alpha=0.1f);
#   %92 = nn.conv2d(%91, %backbone_conv_res_block3_res5_conv2_conv_weight, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]);
#   %93 = nn.batch_norm(%92, %backbone_conv_res_block3_res5_conv2_bn_weight, %backbone_conv_res_block3_res5_conv2_bn_bias, %backbone_conv_res_block3_res5_conv2_bn_running_mean, %backbone_conv_res_block3_res5_conv2_bn_running_var);
#   %94 = %93.0;
#   %95 = nn.leaky_relu(%94, alpha=0.1f);
#   %96 = add(%95, %87);
#   %97 = nn.conv2d(%96, %backbone_conv_res_block3_res6_conv1_conv_weight, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %98 = nn.batch_norm(%97, %backbone_conv_res_block3_res6_conv1_bn_weight, %backbone_conv_res_block3_res6_conv1_bn_bias, %backbone_conv_res_block3_res6_conv1_bn_running_mean, %backbone_conv_res_block3_res6_conv1_bn_running_var);
#   %99 = %98.0;
#   %100 = nn.leaky_relu(%99, alpha=0.1f);
#   %101 = nn.conv2d(%100, %backbone_conv_res_block3_res6_conv2_conv_weight, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]);
#   %102 = nn.batch_norm(%101, %backbone_conv_res_block3_res6_conv2_bn_weight, %backbone_conv_res_block3_res6_conv2_bn_bias, %backbone_conv_res_block3_res6_conv2_bn_running_mean, %backbone_conv_res_block3_res6_conv2_bn_running_var);
#   %103 = %102.0;
#   %104 = nn.leaky_relu(%103, alpha=0.1f);
#   %105 = add(%104, %96);
#   %106 = nn.conv2d(%105, %backbone_conv_res_block3_res7_conv1_conv_weight, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %107 = nn.batch_norm(%106, %backbone_conv_res_block3_res7_conv1_bn_weight, %backbone_conv_res_block3_res7_conv1_bn_bias, %backbone_conv_res_block3_res7_conv1_bn_running_mean, %backbone_conv_res_block3_res7_conv1_bn_running_var);
#   %108 = %107.0;
#   %109 = nn.leaky_relu(%108, alpha=0.1f);
#   %110 = nn.conv2d(%109, %backbone_conv_res_block3_res7_conv2_conv_weight, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]);
#   %111 = nn.batch_norm(%110, %backbone_conv_res_block3_res7_conv2_bn_weight, %backbone_conv_res_block3_res7_conv2_bn_bias, %backbone_conv_res_block3_res7_conv2_bn_running_mean, %backbone_conv_res_block3_res7_conv2_bn_running_var);
#   %112 = %111.0;
#   %113 = nn.leaky_relu(%112, alpha=0.1f);
#   %114 = add(%113, %105);
#   %115 = nn.conv2d(%114, %backbone_conv_res_block4_conv_conv_weight, strides=[2, 2], padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]);
#   %116 = nn.batch_norm(%115, %backbone_conv_res_block4_conv_bn_weight, %backbone_conv_res_block4_conv_bn_bias, %backbone_conv_res_block4_conv_bn_running_mean, %backbone_conv_res_block4_conv_bn_running_var);
#   %117 = %116.0;
#   %118 = nn.leaky_relu(%117, alpha=0.1f);
#   %119 = nn.conv2d(%118, %backbone_conv_res_block4_res0_conv1_conv_weight, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]);
#   %120 = nn.batch_norm(%119, %backbone_conv_res_block4_res0_conv1_bn_weight, %backbone_conv_res_block4_res0_conv1_bn_bias, %backbone_conv_res_block4_res0_conv1_bn_running_mean, %backbone_conv_res_block4_res0_conv1_bn_running_var);
#   %121 = %120.0;
#   %122 = nn.leaky_relu(%121, alpha=0.1f);
#   %123 = nn.conv2d(%122, %backbone_conv_res_block4_res0_conv2_conv_weight, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]);
#   %124 = nn.batch_norm(%123, %backbone_conv_res_block4_res0_conv2_bn_weight, %backbone_conv_res_block4_res0_conv2_bn_bias, %backbone_conv_res_block4_res0_conv2_bn_running_mean, %backbone_conv_res_block4_res0_conv2_bn_running_var);
#   %125 = %124.0;
#   %126 = nn.leaky_relu(%125, alpha=0.1f);
#   %127 = add(%126, %118);
#   %128 = nn.conv2d(%127, %backbone_conv_res_block4_res1_conv1_conv_weight, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]);
#   %129 = nn.batch_norm(%128, %backbone_conv_res_block4_res1_conv1_bn_weight, %backbone_conv_res_block4_res1_conv1_bn_bias, %backbone_conv_res_block4_res1_conv1_bn_running_mean, %backbone_conv_res_block4_res1_conv1_bn_running_var);
#   %130 = %129.0;
#   %131 = nn.leaky_relu(%130, alpha=0.1f);
#   %132 = nn.conv2d(%131, %backbone_conv_res_block4_res1_conv2_conv_weight, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]);
#   %133 = nn.batch_norm(%132, %backbone_conv_res_block4_res1_conv2_bn_weight, %backbone_conv_res_block4_res1_conv2_bn_bias, %backbone_conv_res_block4_res1_conv2_bn_running_mean, %backbone_conv_res_block4_res1_conv2_bn_running_var);
#   %134 = %133.0;
#   %135 = nn.leaky_relu(%134, alpha=0.1f);
#   %136 = add(%135, %127);
#   %137 = nn.conv2d(%136, %backbone_conv_res_block4_res2_conv1_conv_weight, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]);
#   %138 = nn.batch_norm(%137, %backbone_conv_res_block4_res2_conv1_bn_weight, %backbone_conv_res_block4_res2_conv1_bn_bias, %backbone_conv_res_block4_res2_conv1_bn_running_mean, %backbone_conv_res_block4_res2_conv1_bn_running_var);
#   %139 = %138.0;
#   %140 = nn.leaky_relu(%139, alpha=0.1f);
#   %141 = nn.conv2d(%140, %backbone_conv_res_block4_res2_conv2_conv_weight, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]);
#   %142 = nn.batch_norm(%141, %backbone_conv_res_block4_res2_conv2_bn_weight, %backbone_conv_res_block4_res2_conv2_bn_bias, %backbone_conv_res_block4_res2_conv2_bn_running_mean, %backbone_conv_res_block4_res2_conv2_bn_running_var);
#   %143 = %142.0;
#   %144 = nn.leaky_relu(%143, alpha=0.1f);
#   %145 = add(%144, %136);
#   %146 = nn.conv2d(%145, %backbone_conv_res_block4_res3_conv1_conv_weight, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]);
#   %147 = nn.batch_norm(%146, %backbone_conv_res_block4_res3_conv1_bn_weight, %backbone_conv_res_block4_res3_conv1_bn_bias, %backbone_conv_res_block4_res3_conv1_bn_running_mean, %backbone_conv_res_block4_res3_conv1_bn_running_var);
#   %148 = %147.0;
#   %149 = nn.leaky_relu(%148, alpha=0.1f);
#   %150 = nn.conv2d(%149, %backbone_conv_res_block4_res3_conv2_conv_weight, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]);
#   %151 = nn.batch_norm(%150, %backbone_conv_res_block4_res3_conv2_bn_weight, %backbone_conv_res_block4_res3_conv2_bn_bias, %backbone_conv_res_block4_res3_conv2_bn_running_mean, %backbone_conv_res_block4_res3_conv2_bn_running_var);
#   %152 = %151.0;
#   %153 = nn.leaky_relu(%152, alpha=0.1f);
#   %154 = add(%153, %145);
#   %155 = nn.conv2d(%154, %backbone_conv_res_block4_res4_conv1_conv_weight, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]);
#   %156 = nn.batch_norm(%155, %backbone_conv_res_block4_res4_conv1_bn_weight, %backbone_conv_res_block4_res4_conv1_bn_bias, %backbone_conv_res_block4_res4_conv1_bn_running_mean, %backbone_conv_res_block4_res4_conv1_bn_running_var);
#   %157 = %156.0;
#   %158 = nn.leaky_relu(%157, alpha=0.1f);
#   %159 = nn.conv2d(%158, %backbone_conv_res_block4_res4_conv2_conv_weight, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]);
#   %160 = nn.batch_norm(%159, %backbone_conv_res_block4_res4_conv2_bn_weight, %backbone_conv_res_block4_res4_conv2_bn_bias, %backbone_conv_res_block4_res4_conv2_bn_running_mean, %backbone_conv_res_block4_res4_conv2_bn_running_var);
#   %161 = %160.0;
#   %162 = nn.leaky_relu(%161, alpha=0.1f);
#   %163 = add(%162, %154);
#   %164 = nn.conv2d(%163, %backbone_conv_res_block4_res5_conv1_conv_weight, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]);
#   %165 = nn.batch_norm(%164, %backbone_conv_res_block4_res5_conv1_bn_weight, %backbone_conv_res_block4_res5_conv1_bn_bias, %backbone_conv_res_block4_res5_conv1_bn_running_mean, %backbone_conv_res_block4_res5_conv1_bn_running_var);
#   %166 = %165.0;
#   %167 = nn.leaky_relu(%166, alpha=0.1f);
#   %168 = nn.conv2d(%167, %backbone_conv_res_block4_res5_conv2_conv_weight, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]);
#   %169 = nn.batch_norm(%168, %backbone_conv_res_block4_res5_conv2_bn_weight, %backbone_conv_res_block4_res5_conv2_bn_bias, %backbone_conv_res_block4_res5_conv2_bn_running_mean, %backbone_conv_res_block4_res5_conv2_bn_running_var);
#   %170 = %169.0;
#   %171 = nn.leaky_relu(%170, alpha=0.1f);
#   %172 = add(%171, %163);
#   %173 = nn.conv2d(%172, %backbone_conv_res_block4_res6_conv1_conv_weight, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]);
#   %174 = nn.batch_norm(%173, %backbone_conv_res_block4_res6_conv1_bn_weight, %backbone_conv_res_block4_res6_conv1_bn_bias, %backbone_conv_res_block4_res6_conv1_bn_running_mean, %backbone_conv_res_block4_res6_conv1_bn_running_var);
#   %175 = %174.0;
#   %176 = nn.leaky_relu(%175, alpha=0.1f);
#   %177 = nn.conv2d(%176, %backbone_conv_res_block4_res6_conv2_conv_weight, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]);
#   %178 = nn.batch_norm(%177, %backbone_conv_res_block4_res6_conv2_bn_weight, %backbone_conv_res_block4_res6_conv2_bn_bias, %backbone_conv_res_block4_res6_conv2_bn_running_mean, %backbone_conv_res_block4_res6_conv2_bn_running_var);
#   %179 = %178.0;
#   %180 = nn.leaky_relu(%179, alpha=0.1f);
#   %181 = add(%180, %172);
#   %182 = nn.conv2d(%181, %backbone_conv_res_block4_res7_conv1_conv_weight, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]);
#   %183 = nn.batch_norm(%182, %backbone_conv_res_block4_res7_conv1_bn_weight, %backbone_conv_res_block4_res7_conv1_bn_bias, %backbone_conv_res_block4_res7_conv1_bn_running_mean, %backbone_conv_res_block4_res7_conv1_bn_running_var);
#   %184 = %183.0;
#   %185 = nn.leaky_relu(%184, alpha=0.1f);
#   %186 = nn.conv2d(%185, %backbone_conv_res_block4_res7_conv2_conv_weight, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]);
#   %187 = nn.batch_norm(%186, %backbone_conv_res_block4_res7_conv2_bn_weight, %backbone_conv_res_block4_res7_conv2_bn_bias, %backbone_conv_res_block4_res7_conv2_bn_running_mean, %backbone_conv_res_block4_res7_conv2_bn_running_var);
#   %188 = %187.0;
#   %189 = nn.leaky_relu(%188, alpha=0.1f);
#   %190 = add(%189, %181);
#   %191 = nn.conv2d(%190, %backbone_conv_res_block5_conv_conv_weight, strides=[2, 2], padding=[1, 1, 1, 1], channels=1024, kernel_size=[3, 3]);
#   %192 = nn.batch_norm(%191, %backbone_conv_res_block5_conv_bn_weight, %backbone_conv_res_block5_conv_bn_bias, %backbone_conv_res_block5_conv_bn_running_mean, %backbone_conv_res_block5_conv_bn_running_var);
#   %193 = %192.0;
#   %194 = nn.leaky_relu(%193, alpha=0.1f);
#   %195 = nn.conv2d(%194, %backbone_conv_res_block5_res0_conv1_conv_weight, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1]);
#   %196 = nn.batch_norm(%195, %backbone_conv_res_block5_res0_conv1_bn_weight, %backbone_conv_res_block5_res0_conv1_bn_bias, %backbone_conv_res_block5_res0_conv1_bn_running_mean, %backbone_conv_res_block5_res0_conv1_bn_running_var);
#   %197 = %196.0;
#   %198 = nn.leaky_relu(%197, alpha=0.1f);
#   %199 = nn.conv2d(%198, %backbone_conv_res_block5_res0_conv2_conv_weight, padding=[1, 1, 1, 1], channels=1024, kernel_size=[3, 3]);
#   %200 = nn.batch_norm(%199, %backbone_conv_res_block5_res0_conv2_bn_weight, %backbone_conv_res_block5_res0_conv2_bn_bias, %backbone_conv_res_block5_res0_conv2_bn_running_mean, %backbone_conv_res_block5_res0_conv2_bn_running_var);
#   %201 = %200.0;
#   %202 = nn.leaky_relu(%201, alpha=0.1f);
#   %203 = add(%202, %194);
#   %204 = nn.conv2d(%203, %backbone_conv_res_block5_res1_conv1_conv_weight, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1]);
#   %205 = nn.batch_norm(%204, %backbone_conv_res_block5_res1_conv1_bn_weight, %backbone_conv_res_block5_res1_conv1_bn_bias, %backbone_conv_res_block5_res1_conv1_bn_running_mean, %backbone_conv_res_block5_res1_conv1_bn_running_var);
#   %206 = %205.0;
#   %207 = nn.leaky_relu(%206, alpha=0.1f);
#   %208 = nn.conv2d(%207, %backbone_conv_res_block5_res1_conv2_conv_weight, padding=[1, 1, 1, 1], channels=1024, kernel_size=[3, 3]);
#   %209 = nn.batch_norm(%208, %backbone_conv_res_block5_res1_conv2_bn_weight, %backbone_conv_res_block5_res1_conv2_bn_bias, %backbone_conv_res_block5_res1_conv2_bn_running_mean, %backbone_conv_res_block5_res1_conv2_bn_running_var);
#   %210 = %209.0;
#   %211 = nn.leaky_relu(%210, alpha=0.1f);
#   %212 = add(%211, %203);
#   %213 = nn.conv2d(%212, %backbone_conv_res_block5_res2_conv1_conv_weight, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1]);
#   %214 = nn.batch_norm(%213, %backbone_conv_res_block5_res2_conv1_bn_weight, %backbone_conv_res_block5_res2_conv1_bn_bias, %backbone_conv_res_block5_res2_conv1_bn_running_mean, %backbone_conv_res_block5_res2_conv1_bn_running_var);
#   %215 = %214.0;
#   %216 = nn.leaky_relu(%215, alpha=0.1f);
#   %217 = nn.conv2d(%216, %backbone_conv_res_block5_res2_conv2_conv_weight, padding=[1, 1, 1, 1], channels=1024, kernel_size=[3, 3]);
#   %218 = nn.batch_norm(%217, %backbone_conv_res_block5_res2_conv2_bn_weight, %backbone_conv_res_block5_res2_conv2_bn_bias, %backbone_conv_res_block5_res2_conv2_bn_running_mean, %backbone_conv_res_block5_res2_conv2_bn_running_var);
#   %219 = %218.0;
#   %220 = nn.leaky_relu(%219, alpha=0.1f);
#   %221 = add(%220, %212);
#   %222 = nn.conv2d(%221, %backbone_conv_res_block5_res3_conv1_conv_weight, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1]);
#   %223 = nn.batch_norm(%222, %backbone_conv_res_block5_res3_conv1_bn_weight, %backbone_conv_res_block5_res3_conv1_bn_bias, %backbone_conv_res_block5_res3_conv1_bn_running_mean, %backbone_conv_res_block5_res3_conv1_bn_running_var);
#   %224 = %223.0;
#   %225 = nn.leaky_relu(%224, alpha=0.1f);
#   %226 = nn.conv2d(%225, %backbone_conv_res_block5_res3_conv2_conv_weight, padding=[1, 1, 1, 1], channels=1024, kernel_size=[3, 3]);
#   %227 = nn.batch_norm(%226, %backbone_conv_res_block5_res3_conv2_bn_weight, %backbone_conv_res_block5_res3_conv2_bn_bias, %backbone_conv_res_block5_res3_conv2_bn_running_mean, %backbone_conv_res_block5_res3_conv2_bn_running_var);
#   %228 = %227.0;
#   %229 = nn.leaky_relu(%228, alpha=0.1f);
#   %230 = add(%229, %221);
#   %231 = (%230, %190, %114);
#   %232 = %231.0;
#   %233 = nn.conv2d(%232, %neck_detect1_conv1_conv_weight, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1]);
#   %234 = nn.batch_norm(%233, %neck_detect1_conv1_bn_weight, %neck_detect1_conv1_bn_bias, %neck_detect1_conv1_bn_running_mean, %neck_detect1_conv1_bn_running_var);
#   %235 = %234.0;
#   %236 = nn.leaky_relu(%235, alpha=0.1f);
#   %237 = nn.conv2d(%236, %neck_detect1_conv2_conv_weight, padding=[1, 1, 1, 1], channels=1024, kernel_size=[3, 3]);
#   %238 = nn.batch_norm(%237, %neck_detect1_conv2_bn_weight, %neck_detect1_conv2_bn_bias, %neck_detect1_conv2_bn_running_mean, %neck_detect1_conv2_bn_running_var);
#   %239 = %238.0;
#   %240 = nn.leaky_relu(%239, alpha=0.1f);
#   %241 = nn.conv2d(%240, %neck_detect1_conv3_conv_weight, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1]);
#   %242 = nn.batch_norm(%241, %neck_detect1_conv3_bn_weight, %neck_detect1_conv3_bn_bias, %neck_detect1_conv3_bn_running_mean, %neck_detect1_conv3_bn_running_var);
#   %243 = %242.0;
#   %244 = nn.leaky_relu(%243, alpha=0.1f);
#   %245 = nn.conv2d(%244, %neck_detect1_conv4_conv_weight, padding=[1, 1, 1, 1], channels=1024, kernel_size=[3, 3]);
#   %246 = nn.batch_norm(%245, %neck_detect1_conv4_bn_weight, %neck_detect1_conv4_bn_bias, %neck_detect1_conv4_bn_running_mean, %neck_detect1_conv4_bn_running_var);
#   %247 = %246.0;
#   %248 = nn.leaky_relu(%247, alpha=0.1f);
#   %249 = nn.conv2d(%248, %neck_detect1_conv5_conv_weight, padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1]);
#   %250 = nn.batch_norm(%249, %neck_detect1_conv5_bn_weight, %neck_detect1_conv5_bn_bias, %neck_detect1_conv5_bn_running_mean, %neck_detect1_conv5_bn_running_var);
#   %251 = %250.0;
#   %252 = nn.leaky_relu(%251, alpha=0.1f);
#   %253 = nn.conv2d(%252, %neck_conv1_conv_weight, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]);
#   %254 = nn.batch_norm(%253, %neck_conv1_bn_weight, %neck_conv1_bn_bias, %neck_conv1_bn_running_mean, %neck_conv1_bn_running_var);
#   %255 = %254.0;
#   %256 = nn.leaky_relu(%255, alpha=0.1f);
#   %257 = image.resize2d(%256, size=[26, 26], roi=[0f, 0f, 0f, 0f], method="nearest_neighbor", coordinate_transformation_mode="asymmetric", rounding_method="", cubic_alpha=-0.75f);
#   %258 = %231.1;
#   %259 = (%257, %258);
#   %260 = concatenate(%259, axis=1);
#   %261 = nn.conv2d(%260, %neck_detect2_conv1_conv_weight, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]);
#   %262 = nn.batch_norm(%261, %neck_detect2_conv1_bn_weight, %neck_detect2_conv1_bn_bias, %neck_detect2_conv1_bn_running_mean, %neck_detect2_conv1_bn_running_var);
#   %263 = %262.0;
#   %264 = nn.leaky_relu(%263, alpha=0.1f);
#   %265 = nn.conv2d(%264, %neck_detect2_conv2_conv_weight, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]);
#   %266 = nn.batch_norm(%265, %neck_detect2_conv2_bn_weight, %neck_detect2_conv2_bn_bias, %neck_detect2_conv2_bn_running_mean, %neck_detect2_conv2_bn_running_var);
#   %267 = %266.0;
#   %268 = nn.leaky_relu(%267, alpha=0.1f);
#   %269 = nn.conv2d(%268, %neck_detect2_conv3_conv_weight, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]);
#   %270 = nn.batch_norm(%269, %neck_detect2_conv3_bn_weight, %neck_detect2_conv3_bn_bias, %neck_detect2_conv3_bn_running_mean, %neck_detect2_conv3_bn_running_var);
#   %271 = %270.0;
#   %272 = nn.leaky_relu(%271, alpha=0.1f);
#   %273 = nn.conv2d(%272, %neck_detect2_conv4_conv_weight, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]);
#   %274 = nn.batch_norm(%273, %neck_detect2_conv4_bn_weight, %neck_detect2_conv4_bn_bias, %neck_detect2_conv4_bn_running_mean, %neck_detect2_conv4_bn_running_var);
#   %275 = %274.0;
#   %276 = nn.leaky_relu(%275, alpha=0.1f);
#   %277 = nn.conv2d(%276, %neck_detect2_conv5_conv_weight, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]);
#   %278 = nn.batch_norm(%277, %neck_detect2_conv5_bn_weight, %neck_detect2_conv5_bn_bias, %neck_detect2_conv5_bn_running_mean, %neck_detect2_conv5_bn_running_var);
#   %279 = %278.0;
#   %280 = nn.leaky_relu(%279, alpha=0.1f);
#   %281 = nn.conv2d(%280, %neck_conv2_conv_weight, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %282 = nn.batch_norm(%281, %neck_conv2_bn_weight, %neck_conv2_bn_bias, %neck_conv2_bn_running_mean, %neck_conv2_bn_running_var);
#   %283 = %282.0;
#   %284 = nn.leaky_relu(%283, alpha=0.1f);
#   %285 = image.resize2d(%284, size=[52, 52], roi=[0f, 0f, 0f, 0f], method="nearest_neighbor", coordinate_transformation_mode="asymmetric", rounding_method="", cubic_alpha=-0.75f);
#   %286 = %231.2;
#   %287 = (%285, %286);
#   %288 = concatenate(%287, axis=1);
#   %289 = nn.conv2d(%288, %neck_detect3_conv1_conv_weight, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %290 = nn.batch_norm(%289, %neck_detect3_conv1_bn_weight, %neck_detect3_conv1_bn_bias, %neck_detect3_conv1_bn_running_mean, %neck_detect3_conv1_bn_running_var);
#   %291 = %290.0;
#   %292 = nn.leaky_relu(%291, alpha=0.1f);
#   %293 = nn.conv2d(%292, %neck_detect3_conv2_conv_weight, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]);
#   %294 = nn.batch_norm(%293, %neck_detect3_conv2_bn_weight, %neck_detect3_conv2_bn_bias, %neck_detect3_conv2_bn_running_mean, %neck_detect3_conv2_bn_running_var);
#   %295 = %294.0;
#   %296 = nn.leaky_relu(%295, alpha=0.1f);
#   %297 = nn.conv2d(%296, %neck_detect3_conv3_conv_weight, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %298 = nn.batch_norm(%297, %neck_detect3_conv3_bn_weight, %neck_detect3_conv3_bn_bias, %neck_detect3_conv3_bn_running_mean, %neck_detect3_conv3_bn_running_var);
#   %299 = %298.0;
#   %300 = nn.leaky_relu(%299, alpha=0.1f);
#   %301 = nn.conv2d(%300, %neck_detect3_conv4_conv_weight, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]);
#   %302 = nn.batch_norm(%301, %neck_detect3_conv4_bn_weight, %neck_detect3_conv4_bn_bias, %neck_detect3_conv4_bn_running_mean, %neck_detect3_conv4_bn_running_var);
#   %303 = %302.0;
#   %304 = nn.leaky_relu(%303, alpha=0.1f);
#   %305 = nn.conv2d(%304, %neck_detect3_conv5_conv_weight, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %306 = nn.batch_norm(%305, %neck_detect3_conv5_bn_weight, %neck_detect3_conv5_bn_bias, %neck_detect3_conv5_bn_running_mean, %neck_detect3_conv5_bn_running_var);
#   %307 = %306.0;
#   %308 = nn.leaky_relu(%307, alpha=0.1f);
#   %309 = (%252, %280, %308);
#   %310 = %309.0;
#   %311 = nn.conv2d(%310, %bbox_head_convs_bridge_0_conv_weight, padding=[1, 1, 1, 1], channels=1024, kernel_size=[3, 3]);
#   %312 = nn.batch_norm(%311, %bbox_head_convs_bridge_0_bn_weight, %bbox_head_convs_bridge_0_bn_bias, %bbox_head_convs_bridge_0_bn_running_mean, %bbox_head_convs_bridge_0_bn_running_var);
#   %313 = %312.0;
#   %314 = nn.leaky_relu(%313, alpha=0.1f);
#   %315 = nn.conv2d(%314, %bbox_head_convs_pred_0_weight, padding=[0, 0, 0, 0], channels=255, kernel_size=[1, 1]);
#   %316 = %309.1;
#   %317 = nn.conv2d(%316, %bbox_head_convs_bridge_1_conv_weight, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]);
#   %318 = nn.batch_norm(%317, %bbox_head_convs_bridge_1_bn_weight, %bbox_head_convs_bridge_1_bn_bias, %bbox_head_convs_bridge_1_bn_running_mean, %bbox_head_convs_bridge_1_bn_running_var);
#   %319 = %318.0;
#   %320 = nn.leaky_relu(%319, alpha=0.1f);
#   %321 = nn.conv2d(%320, %bbox_head_convs_pred_1_weight, padding=[0, 0, 0, 0], channels=255, kernel_size=[1, 1]);
#   %322 = %309.2;
#   %323 = nn.conv2d(%322, %bbox_head_convs_bridge_2_conv_weight, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]);
#   %324 = nn.batch_norm(%323, %bbox_head_convs_bridge_2_bn_weight, %bbox_head_convs_bridge_2_bn_bias, %bbox_head_convs_bridge_2_bn_running_mean, %bbox_head_convs_bridge_2_bn_running_var);
#   %325 = %324.0;
#   %326 = nn.leaky_relu(%325, alpha=0.1f);
#   %327 = nn.conv2d(%326, %bbox_head_convs_pred_2_weight, padding=[0, 0, 0, 0], channels=255, kernel_size=[1, 1]);
#   %328 = nn.bias_add(%315, %bbox_head_convs_pred_0_bias);
#   %329 = nn.bias_add(%321, %bbox_head_convs_pred_1_bias);
#   %330 = nn.bias_add(%327, %bbox_head_convs_pred_2_bias);
#   %331 = (%328, %329, %330);
#   %332 = %331.0;
#   %333 = %331.1;
#   %334 = %331.2;
#   %335 = (%332, %333, %334);
#   (%335,)
# }
